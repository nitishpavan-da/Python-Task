# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X = pd.read_csv("train.csv")
X.head(3)
# Out:
#    data1  data2 data3      data4   data5  data6     data7  data8 data9 data10  \
# 0      8    279     C  14.451155  1139.0    1.0  9.302908    1.0     M      p
# 1      1    108     H  14.207448  1656.0    1.0  7.220130    0.0     M      p
# 2      8    258     A  19.220830  2817.0    1.0  8.727214    1.0     M      p
#
#       output
# 0  86.108947
# 1  42.606833
# 2  85.625961

# %%
X["data10"] = pd.get_dummies(X["data10"])

# %%
X.head(4)
# Out:
#    data1  data2 data3      data4   data5  data6     data7  data8 data9  \
# 0      8    279     C  14.451155  1139.0    1.0  9.302908    1.0     M
# 1      1    108     H  14.207448  1656.0    1.0  7.220130    0.0     M
# 2      8    258     A  19.220830  2817.0    1.0  8.727214    1.0     M
# 3      4    147     A  15.752732  1948.0    1.0  6.078818    1.0     M
#
#    data10     output
# 0       1  86.108947
# 1       1  42.606833
# 2       1  85.625961
# 3       1  53.656277

# %%
X["data9"] = pd.get_dummies(X["data9"])

# %%
X.head(5)
# Out:
#    data1  data2 data3      data4   data5  data6     data7  data8  data9  \
# 0      8    279     C  14.451155  1139.0    1.0  9.302908    1.0      0
# 1      1    108     H  14.207448  1656.0    1.0  7.220130    0.0      0
# 2      8    258     A  19.220830  2817.0    1.0  8.727214    1.0      0
# 3      4    147     A  15.752732  1948.0    1.0  6.078818    1.0      0
# 4      5    230     H  10.195407  1336.0    1.0  4.749185    0.0      0
#
#    data10     output
# 0       1  86.108947
# 1       1  42.606833
# 2       1  85.625961
# 3       1  53.656277
# 4       1  64.925051

# %%
X["data9"].value_counts()
# Out:
# 0    6000
# 1    4000
# Name: data9, dtype: int64

# %%
plt.scatter(X["data1"], X["output"])

# %%
X.isnull().sum()
# Out:
# data1     0
# data2     0
# data3     0
# data4     0
# data5     1
# data6     3
# data7     2
# data8     1
# data9     0
# data10    0
# output    1
# dtype: int64

# %%
X.head(4)
# Out:
#    data1  data2 data3      data4   data5  data6     data7  data8  data9  \
# 0      8    279     C  14.451155  1139.0    1.0  9.302908    1.0      0
# 1      1    108     H  14.207448  1656.0    1.0  7.220130    0.0      0
# 2      8    258     A  19.220830  2817.0    1.0  8.727214    1.0      0
# 3      4    147     A  15.752732  1948.0    1.0  6.078818    1.0      0
#
#    data10     output
# 0       1  86.108947
# 1       1  42.606833
# 2       1  85.625961
# 3       1  53.656277

# %%
X["data4"] = X["data4"].round(3)

# %%
X["data7"] = X["data7"].round(3)

# %%
X["output"] = X["output"].round(3)

# %%
X.head(5)
# Out:
#    data1  data2 data3   data4   data5  data6  data7  data8  data9  data10  \
# 0      8    279     C  14.451  1139.0    1.0  9.303    1.0      0       1
# 1      1    108     H  14.207  1656.0    1.0  7.220    0.0      0       1
# 2      8    258     A  19.221  2817.0    1.0  8.727    1.0      0       1
# 3      4    147     A  15.753  1948.0    1.0  6.079    1.0      0       1
# 4      5    230     H  10.195  1336.0    1.0  4.749    0.0      0       1
#
#    output
# 0  86.109
# 1  42.607
# 2  85.626
# 3  53.656
# 4  64.925

# %%
X = X.fillna({
    "data5" : np.round(np.mean(X["data5"]), 2),
    "data6" : np.round(np.mean(X["data6"]), 2),
    "data7" : np.round(np.mean(X["data7"]), 2),
    "data8" : np.round(np.mean(X["data8"]), 2),
    "output": np.round(np.mean(X["output"]),2)
})

# %%
X.isnull().sum()
# Out:
# data1     0
# data2     0
# data3     0
# data4     0
# data5     0
# data6     0
# data7     0
# data8     0
# data9     0
# data10    0
# output    0
# dtype: int64

# %%
X.head(4)
# Out:
#    data1  data2 data3   data4   data5  data6  data7  data8  data9  data10  \
# 0      8    279     C  14.451  1139.0    1.0  9.303    1.0      0       1
# 1      1    108     H  14.207  1656.0    1.0  7.220    0.0      0       1
# 2      8    258     A  19.221  2817.0    1.0  8.727    1.0      0       1
# 3      4    147     A  15.753  1948.0    1.0  6.079    1.0      0       1
#
#    output
# 0  86.109
# 1  42.607
# 2  85.626
# 3  53.656

# %%
Trash_Data = X.drop("data3", axis = 1)

# %%
Trash_Data.head()
# Out:
#    data1  data2   data4   data5  data6  data7  data8  data9  data10  output
# 0      8    279  14.451  1139.0    1.0  9.303    1.0      0       1  86.109
# 1      1    108  14.207  1656.0    1.0  7.220    0.0      0       1  42.607
# 2      8    258  19.221  2817.0    1.0  8.727    1.0      0       1  85.626
# 3      4    147  15.753  1948.0    1.0  6.079    1.0      0       1  53.656
# 4      5    230  10.195  1336.0    1.0  4.749    0.0      0       1  64.925

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder().fit_transform(X["data3"])

# %%
Trash_Data["data3"] = label

# %%
Trash_Data
# Out:
#       data1  data2   data4   data5  data6  data7  data8  data9  data10  \
# 0         8    279  14.451  1139.0    1.0  9.303    1.0      0       1
# 1         1    108  14.207  1656.0    1.0  7.220    0.0      0       1
# 2         8    258  19.221  2817.0    1.0  8.727    1.0      0       1
# 3         4    147  15.753  1948.0    1.0  6.079    1.0      0       1
# 4         5    230  10.195  1336.0    1.0  4.749    0.0      0       1
# ...     ...    ...     ...     ...    ...    ...    ...    ...     ...
# 9995      9    263  16.604  1070.0    0.0  8.979    2.0      1       1
# 9996      5    280  28.759  2652.0    0.0  3.574    0.0      1       1
# 9997      6    188  15.963  1359.0    0.0  2.880    0.0      1       1
# 9998      1    132  11.683  1793.0    0.0  6.983    2.0      1       1
# 9999      5    264  21.176  1792.0    0.0  8.276    2.0      1       1
#
#       output  data3
# 0     86.109      2
# 1     42.607      7
# 2     85.626      0
# 3     53.656      0
# ...

# %%
max_thresh = Trash_Data["data1"].quantile(0.95)

# %%
max_thresh
# Out:
# 9.0

# %%
Trash_Data["data1"] = np.where(Trash_Data["data1"] > max_thresh, np.median(Trash_Data["data1"] <= max_thresh), Trash_Data["data1"])

# %%
Trash_Data.head()
# Out:
#    data1  data2   data4   data5  data6  data7  data8  data9  data10  output  \
# 0    8.0    279  14.451  1139.0    1.0  9.303    1.0      0       1  86.109
# 1    1.0    108  14.207  1656.0    1.0  7.220    0.0      0       1  42.607
# 2    8.0    258  19.221  2817.0    1.0  8.727    1.0      0       1  85.626
# 3    4.0    147  15.753  1948.0    1.0  6.079    1.0      0       1  53.656
# 4    5.0    230  10.195  1336.0    1.0  4.749    0.0      0       1  64.925
#
#    data3
# 0      2
# 1      7
# 2      0
# 3      0
# 4      7

# %%
plt.scatter(Trash_Data["data1"], Trash_Data["output"])

# %%
New_Data = Trash_Data.copy()

# %%
New_Data.head(4)
# Out:
#    data1  data2   data4   data5  data6  data7  data8  data9  data10  output  \
# 0    8.0    279  14.451  1139.0    1.0  9.303    1.0      0       1  86.109
# 1    1.0    108  14.207  1656.0    1.0  7.220    0.0      0       1  42.607
# 2    8.0    258  19.221  2817.0    1.0  8.727    1.0      0       1  85.626
# 3    4.0    147  15.753  1948.0    1.0  6.079    1.0      0       1  53.656
#
#    data3
# 0      2
# 1      7
# 2      0
# 3      0

# %%
y = pd.read_csv("test.csv")
y.head()
# Out:
#    data1  data2 data3      data4  data5  data6     data7  data8 data9 data10
# 0      7    195     A  29.038043   2725      1  6.145731      2     M      p
# 1      9    109     F  20.221431   1184      1  9.334184      2     M      p
# 2      0    126     C  26.477532   2975      1  9.021806      1     M      p
# 3      2    209     E  13.445450   1067      1  1.814993      0     M      p
# 4      5    268     B  25.065894   1336      1  1.639130      1     M      p

# %%
y["data10"] = pd.get_dummies(y["data10"])
y.head()
# Out:
#    data1  data2 data3      data4  data5  data6     data7  data8 data9  data10
# 0      7    195     A  29.038043   2725      1  6.145731      2     M       1
# 1      9    109     F  20.221431   1184      1  9.334184      2     M       1
# 2      0    126     C  26.477532   2975      1  9.021806      1     M       1
# 3      2    209     E  13.445450   1067      1  1.814993      0     M       1
# 4      5    268     B  25.065894   1336      1  1.639130      1     M       1

# %%
y["data9"] = pd.get_dummies(y["data9"])
y.head(3)
# Out:
#    data1  data2 data3      data4  data5  data6     data7  data8  data9  data10
# 0      7    195     A  29.038043   2725      1  6.145731      2      0       1
# 1      9    109     F  20.221431   1184      1  9.334184      2      0       1
# 2      0    126     C  26.477532   2975      1  9.021806      1      0       1

# %%
y["data4"] = y["data4"].round(3)

# %%
y["data7"] = y["data7"].round(3)

# %%
y.head()
# Out:
#    data1  data2 data3   data4  data5  data6  data7  data8  data9  data10
# 0      7    195     A  29.038   2725      1  6.146      2      0       1
# 1      9    109     F  20.221   1184      1  9.334      2      0       1
# 2      0    126     C  26.478   2975      1  9.022      1      0       1
# 3      2    209     E  13.445   1067      1  1.815      0      0       1
# 4      5    268     B  25.066   1336      1  1.639      1      0       1

# %%
label_1 = LabelEncoder().fit_transform(y["data3"])

# %%
Trash_Data1 = y.drop("data3", axis = 1)

# %%
Trash_Data1["data3"] = label_1

# %%
Trash_Data1.head(4)
# Out:
#    data1  data2   data4  data5  data6  data7  data8  data9  data10  data3
# 0      7    195  29.038   2725      1  6.146      2      0       1      0
# 1      9    109  20.221   1184      1  9.334      2      0       1      5
# 2      0    126  26.478   2975      1  9.022      1      0       1      2
# 3      2    209  13.445   1067      1  1.815      0      0       1      4

# %%
New_Data1 = Trash_Data1.copy()

# %%
New_Data1.head(2)
# Out:
#    data1  data2   data4  data5  data6  data7  data8  data9  data10  data3
# 0      7    195  29.038   2725      1  6.146      2      0       1      0
# 1      9    109  20.221   1184      1  9.334      2      0       1      5

# %%
from sklearn import preprocessing
train = preprocessing.StandardScaler().fit_transform(New_Data)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(New_Data, New_Data1, test_size = 0.3, random_state = 20)

# %%
X_train.shape
# Out:
# (7000, 11)

# %%
X_test.shape
# Out:
# (3000, 11)

# %%
y_train.shape
# Out:
# (7000, 10)

# %%
y_test.shape
# Out:
# (3000, 10)

# %%
#from sklearn.neighbors import KNeighborsClassifier
#knnmodel = KNeighborsClassifier(n_neighbors = 5)
#knnmodel.fit(X_train, y_train)
#y_predict = knnmodel.predict(X_test)

# %%
plt.plot(New_Data["data7"], New_Data["output"])

# %%
New_Data.head(4)
# Out:
#    data1  data2   data4   data5  data6  data7  data8  data9  data10  output  \
# 0    8.0    279  14.451  1139.0    1.0  9.303    1.0      0       1  86.109
# 1    1.0    108  14.207  1656.0    1.0  7.220    0.0      0       1  42.607
# 2    8.0    258  19.221  2817.0    1.0  8.727    1.0      0       1  85.626
# 3    4.0    147  15.753  1948.0    1.0  6.079    1.0      0       1  53.656
#
#    data3
# 0      2
# 1      7
# 2      0
# 3      0

# %%
New_Data1.head()
# Out:
#    data1  data2   data4  data5  data6  data7  data8  data9  data10  data3
# 0      7    195  29.038   2725      1  6.146      2      0       1      0
# 1      9    109  20.221   1184      1  9.334      2      0       1      5
# 2      0    126  26.478   2975      1  9.022      1      0       1      2
# 3      2    209  13.445   1067      1  1.815      0      0       1      4
# 4      5    268  25.066   1336      1  1.639      1      0       1      1

# %%
New_Data1.head()
# Out:
#    data1  data2   data4  data5  data6  data7  data8  data9  data10  data3
# 0      7    195  29.038   2725      1  6.146      2      0       1      0
# 1      9    109  20.221   1184      1  9.334      2      0       1      5
# 2      0    126  26.478   2975      1  9.022      1      0       1      2
# 3      2    209  13.445   1067      1  1.815      0      0       1      4
# 4      5    268  25.066   1336      1  1.639      1      0       1      1

# %%
df = New_Data1.copy()

# %%
from sklearn import linear_model
regression_model = linear_model.LinearRegression().fit(New_Data[["data1","data4","data7"]],New_Data["output"])

# %%
prediction = regression_model.predict(New_Data1[["data1","data4", "data7"]])

# %%
prediction
# Out:
# array([79.71600091, 76.61553852, 72.84747726, ..., 76.03161392,
#        67.59104641, 72.58978053])

# %%
regression_model.coef_
# Out:
# array([1.03176835, 0.9292491 , 0.95018514])

# %%
regression_model.intercept_
# Out:
# 39.67024919195109

# %%
df["predicted output"] = prediction

# %%
df.head(10)
# Out:
#    data1  data2   data4  data5  data6  data7  data8  data9  data10  data3  \
# 0      7    195  29.038   2725      1  6.146      2      0       1      0
# 1      9    109  20.221   1184      1  9.334      2      0       1      5
# 2      0    126  26.478   2975      1  9.022      1      0       1      2
# 3      2    209  13.445   1067      1  1.815      0      0       1      4
# 4      5    268  25.066   1336      1  1.639      1      0       1      1
# 5      7    156  27.580   2324      1  2.401      2      0       1      0
# 6      8    176  19.316   2986      1  2.990      2      0       1      0
# 7      0    117  27.356   2989      1  7.504      1      0       1      3
# 8      8    258  17.453   1919      1  4.857      1      0       1      0
# 9      4    109  10.665   1491      1  3.142      1      0       1      4
#
#    predicted output
# 0         79.716001
# 1         76.615539
# 2         72.847477
# 3         55.952126
# 4         69.679002
# 5         74.802712
# ...

# %%
df.to_csv("final.csv")
